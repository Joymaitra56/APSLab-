# %% [markdown]
# <a href="https://colab.research.google.com/github/Joymaitra56/APSLab-/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}
result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
graph = {}
keys = input("Enter the list of all nodes: ").split()
for i in keys:
  adj = input(f"Enter the nodes connected to node {i}: ").split()
  dist = {}
  for j in adj:
    d = int(input(f"Enter the dist from {i} to {j}: "))
    dist[j] = d
  graph[i] = dist
# Out:
# Enter the list of all nodes: a b c d
# Enter the nodes connected to node a: b c
# Enter the dist from a to b: 4
# Enter the dist from a to c: 3
# Enter the nodes connected to node b: a c d
# Enter the dist from b to a: 6
# Enter the dist from b to c: 7
# Enter the dist from b to d: 3
# Enter the nodes connected to node c: a b d
# Enter the dist from c to a: 2
# Enter the dist from c to b: 4
# Enter the dist from c to d: 1
# Enter the nodes connected to node d: b c
# Enter the dist from d to b: 2
# Enter the dist from d to c: 3

# %%
start = 'a'
result = dijkstra(graph,start)
furthest = max(result.keys())
print(f"Shortest path: {start} to {furthest} with total distance {result[furthest]}")
# Out:
# Shortest path: a to d with total distance 4

# %%
graph['e'] = {"b":8,"a":1,"d":3}
graph['d']['e'] = 3
graph['a']['e'] = 1
graph['b']['e'] = 4
graph
# Out:
# {'a': {'b': 4, 'c': 3, 'e': 1},
#  'b': {'a': 6, 'c': 7, 'd': 3, 'e': 4},
#  'c': {'a': 2, 'b': 4, 'd': 1},
#  'd': {'b': 2, 'c': 3, 'e': 3},
#  'e': {'b': 8, 'a': 1, 'd': 3}}

# %%
start = 'b'
result = dijkstra(graph,start)
furthest = max(result.keys())
print(f"Shortest path: {start} to {furthest} with total distance {result[furthest]}")

start = 'c'
result = dijkstra(graph,start)
furthest = max(result.keys())
print(f"Shortest path: {start} to {furthest} with total distance {result[furthest]}")

start = 'd'
result = dijkstra(graph,start)
furthest = max(result.keys())
print(f"Shortest path: {start} to {furthest} with total distance {result[furthest]}")
# Out:
# Shortest path: b to e with total distance 4
# Shortest path: c to e with total distance 3
# Shortest path: d to e with total distance 3
